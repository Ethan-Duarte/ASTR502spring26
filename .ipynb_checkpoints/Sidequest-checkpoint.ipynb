# %% [markdown]
# Notebook for Dr. Mann's sidequest on TOI-6255, TOI-1807, TOI-2260, TOI-2431, and TOI-431

# %%
import json
from astroquery.gaia import Gaia
from pathlib import Path

CREDS_PATH = Path("gaia_credentials.json")

with CREDS_PATH.open("r", encoding="utf-8") as f:
    creds = json.load(f)

Gaia.login(user=creds["user"], password=creds["password"])
print("Gaia login OK")
# Out:
# Some IP addresses of users launching heavy query showers have temporarily been disabled. Please contact the Gaia helpdesk (https://www.cosmos.esa.int/web/gaia/gaia-helpdesk) for advice. Workaround solutions for the Gaia Archive issues following the infrastructure upgrade: https://www.cosmos.esa.int/web/gaia/news#WorkaroundArchive
# INFO: Login to gaia TAP server [astroquery.gaia.core]
# INFO: OK [astroquery.utils.tap.core]
# INFO: Login to gaia data server [astroquery.gaia.core]
# INFO: OK [astroquery.utils.tap.core]
# Gaia login OK

# %%
import run_stars

run_stars.run(
    mode=1,
    csv_path="Targets.csv",
    hostnames=["TOI-6255", "TOI-1807", "TOI-2260", "TOI-2431", "TOI-431"],
    vlim=3.0,
    srad=30.0,
    verbose=True,
    attempt_timeout_s=1200,
    max_attempts=1,
    all_runs_dir="ALL_RUNS(Sidequest)",
    all_csvs_dir="ALL_CSVS(Sidequest)",
    force_rerun=True,
)
# Out:
# Logging to: C:\Users\Eef\MY SHIT\Documents\ASTR502spring26\ASTR502spring26\run_log.csv
#
# [4275] TOI-6255 | Gaia DR3 1956328333130770048 | RV=-17.82416534
# INFO: Query finished. [astroquery.utils.tap.core]
#   Attempt 1/1 (timeout=1200s)
#   Runtime: 26.43 s (attempt 1)
#   Saved run folder -> ALL_RUNS(Sidequest)\TOI-6255_friends
#
# [1061] TOI-1807 | Gaia DR3 1476485996883837184 | RV=-7.143650532
# INFO: Query finished. [astroquery.utils.tap.core]
#   Attempt 1/1 (timeout=1200s)
#   Runtime: 38.47 s (attempt 1)
#   Saved run folder -> ALL_RUNS(Sidequest)\TOI-1807_friends
#
# [1255] TOI-2260 | Gaia DR3 1411414596649598208 | RV=-28.75943947
# INFO: Query finished. [astroquery.utils.tap.core]
#   Attempt 1/1 (timeout=1200s)
#   Runtime: 175.30 s (attempt 1)
#   Saved run folder -> ALL_RUNS(Sidequest)\TOI-2260_friends
#
# [4449] TOI-2431 | Gaia DR3 22707874346819712 | RV=12.09
# INFO: Query finished. [astroquery.utils.tap.core]
#   Attempt 1/1 (timeout=1200s)
#   Runtime: 28.18 s (attempt 1)
#   Saved run folder -> ALL_RUNS(Sidequest)\TOI-2431_friends
#
# [385] TOI-431 | Gaia DR3 2908664557091200768 | RV=48.66480637
# INFO: Query finished. [astroquery.utils.tap.core]
#   Attempt 1/1 (timeout=1200s)
#   Runtime: 26.43 s (attempt 1)
#   Saved run folder -> ALL_RUNS(Sidequest)\TOI-431_friends

# %%
import Comove

outdir = Comove.findfriends(
    "TOI-2431",
    12.09,
    velocity_limit=5.0,
    search_radius=100.0,
    radec=[37.763667, 8.381994],
    output_directory=None,
    verbose=True,
    showplots=False,
)
print("Returned:", outdir)

# %%
from astroquery.gaia import Gaia

source_id = 22707874346819712

query = f"""
SELECT source_id, ra, dec, parallax, pmra, pmdec, phot_g_mean_mag
FROM gaiadr3.gaia_source
WHERE source_id = {source_id}
"""

job = Gaia.launch_job(query)
r = job.get_results()
print(r)
