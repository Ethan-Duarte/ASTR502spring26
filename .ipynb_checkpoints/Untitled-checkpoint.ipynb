# %%
run run_stars
# Out:
# ...
# Logging to: C:\Users\Eef\MY SHIT\Documents\ASTR502spring26\run_log.csv
#
# [7] Gliese_12 | Gaia DR3 2768048564768256512 | RV=51.04111099
# INFO: Query finished. [astroquery.utils.tap.core]
#   NOTE: distance ~12.17 pc; cap-by-distance: srad -> 10.95 pc
#   NOTE: cone would be huge; cap-by-angle 10.0°: 10.95 -> 2.11 pc
#   Attempt 1/4 (timeout=300s)
#   ERROR (attempt 1/4): ValueError('max() arg is an empty sequence')
#   Runtime: 19.32 s
#
# [8] WASP-32 | Gaia DR3 2546413408888429696 | RV=18.27012634
# 404 Error 404:
# Job 'e6ab627c-1143-11f1-91f6-bc97e148b76b-O' not found.
#   Attempt 1/4 (timeout=300s)
#   ERROR (attempt 1/4): HTTPError('Error 500:\nnull')
#   Runtime: 13.45 s
#   Retrying after 10s...
