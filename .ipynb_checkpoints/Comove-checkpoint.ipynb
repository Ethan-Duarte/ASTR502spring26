# %% [markdown]
# Setup

# %%
import Comove
# Out:
# Warning: the passwords of all user accounts have been inactivated.              Please visit https://cas.cosmos.esa.int/cas/passwd to set a new one. Workaround solutions for the Gaia Archive issues following the infrastructure upgrade: https://www.cosmos.esa.int/web/gaia/news#WorkaroundArchive
# DEBUG 0
# DEBUG 1

# %%
import astropy.units as u
from astropy.coordinates import SkyCoord
from astroquery.gaia import Gaia
import numpy as np
from astroquery.simbad import Simbad

arr = np.genfromtxt(
    "Targets.csv",
    delimiter=",",
    dtype=str,
    encoding="utf-8"
)

"""
--Header to ids-- 
hostname = 1
gaia id  = 2
ra       = 6
dec      = 7
st_rv    = 21
st_e_rv  = 22
"""

print(arr[505][1])

# Code to Pull RV's (No Longer Needed)
"""
host = []
rv = []
for i in range(50, 100):
    #print(arr[i][2])
    if arr[i][2] != arr[i + 1][2]:
        print("yay im different")
        
        coord = SkyCoord(ra=arr[i + 1][6], dec=arr[i + 1][7], unit=(u.degree, u.degree), frame='icrs')
        width = u.Quantity(0.1, u.deg)
        height = u.Quantity(0.1, u.deg)
        r = Gaia.query_object_async(coordinate=coord, width=width, height=height)
        #INFO: Query finished. [astroquery.utils.tap.core]
        #r.pprint(max_lines=12, max_width=130)
        #print(r["radial_velocity"][0])
        
        for j in range(len(r)):
            if r[j][2] == arr[i + 1][2]:
                rv.append(r["radial_velocity"][j])
                host.append(r["source_id"][j])
    else:
        print("samesies")
        rv.append("-")
        host.append("-")
        
np.savetxt("rv.csv", rv, delimiter=",", fmt="%s")
np.savetxt("host.csv", host, delimiter=",", fmt="%s")
"""
# Out:
# TOI-6448
# '\nhost = []\nrv = []\nfor i in range(50, 100):\n    #print(arr[i][2])\n    if arr[i][2] != arr[i + 1][2]:\n        print("yay im different")\n\n        coord = SkyCoord(ra=arr[i + 1][6], dec=arr[i + 1][7], unit=(u.degree, u.degree), frame=\'icrs\')\n        width = u.Quantity(0.1, u.deg)\n        height = u.Quantity(0.1, u.deg)\n        r = Gaia.query_object_async(coordinate=coord, width=width, height=height)\n        #INFO: Query finished. [astroquery.utils.tap.core]\n        #r.pprint(max_lines=12, max_width=130)\n        #print(r["radial_velocity"][0])\n\n        for j in range(len(r)):\n            if r[j][2] == arr[i + 1][2]:\n                rv.append(r["radial_velocity"][j])\n                host.append(r["source_id"][j])\n    else:\n        print("samesies")\n        rv.append("-")\n        host.append("-")\n\nnp.savetxt("rv.csv", rv, delimiter=",", fmt="%s")\nnp.savetxt("host.csv", host, delimiter=",", fmt="%s")\n'

# %%
Simbad.server = "simbad.cds.unistra.fr"

targetIndex = 1151
## Define the inputs:
##An target star name searchable on simbad. If coordinates are used, it will just be used as the default results directory
targname=f"Gaia DR3 {arr[targetIndex][2]}"

##Alternative is to use coordinates, default is [None,None] in which case the targname is used to get coordinates
#rd = [None,None]
rd = [arr[targetIndex][6], arr[targetIndex][7]]

##input target star radial velocity to calulate 3D space velocities
radvel=float(arr[targetIndex][21]) ##km/s

##Neighbour velocity difference limit, and on sky search radius
vlim=4.0 ##km/s
srad=25.0 ##parsecs (spherical radius around target)


##This line runs the entire code. Set showplots=True to interactively plot, otherwise they are only saved as pngs
##Set verbose=True to see LOTS of print output
output_location = Comove.findfriends(targname,radvel,velocity_limit=vlim,search_radius=srad,output_directory=None,verbose=True,showplots=False)
# Out:
# Asking Simbad for RA and DEC
# Target name:  Gaia DR3 1490845584382687232
# Coordinates: 217.39267753064 39.79042868986001
#
# <SkyCoord (ICRS): (ra, dec) in deg
#     (217.39267753, 39.79042869)>
# Asking Gaia for precise coordinates
# INFO: Query finished. [astroquery.utils.tap.core]
# SELECT * FROM gaiadr3.gaia_source WHERE CONTAINS(                POINT('ICRS',gaiadr3.gaia_source.ra,gaiadr3.gaia_source.dec),                CIRCLE('ICRS',217.39267753064,39.79042868986001,0.0016666666666666668))=1;
#
#      source_id              ra                dec        phot_g_mean_mag      parallax         ruwe
#                            deg                deg              mag              mas
# ------------------- ------------------ ----------------- --------------- ------------------ ----------
# 1490845584382687232 217.39199460197628 39.79039820380879        8.918078 23.805198940613547 0.97615695
# None
#
# [False]
# <SkyCoord (ICRS): (ra, dec, distance) in (deg, deg, pc)
#     (217.3919946, 39.7903982, 42.00763045)
#  (pm_ra_cosdec, pm_dec, radial_velocity) in (mas / yr, mas / yr, km / s)
#     (-118.0706747, -6.85984722, -13.07619095)>
#
# Search radius in deg:  36.5218981706045 deg
# Minimum parallax:  14.92367351617861 mas
# Querying Gaia for neighbors
# Parallax cut:  2.380519894061355
# SELECT * FROM gaiadr3.gaia_source WHERE CONTAINS(             POINT('ICRS',gaiadr3.gaia_source.ra,gaiadr3.gaia_source.dec),             CIRCLE('ICRS',217.39199460197628,39.79039820380879,36.5218981706045))            =1 AND parallax>14.92367351617861 AND parallax_error<2.380519894061355;
#
# 500 Error 500:
# null
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 22
#      17 srad=25.0 ##parsecs (spherical radius around target)
#      20 ##This line runs the entire code. Set showplots=True to interactively plot, otherwise they are only saved as pngs
#      21 ##Set verbose=True to see LOTS of print output
# ---> 22 output_location = Comove.findfriends(targname,radvel,velocity_limit=vlim,search_radius=srad,output_directory=None,verbose=True,showplots=False)
#
# File ~\ASTR502\ASTR502spring26\Comove.py:174, in findfriends(targname, radial_velocity, velocity_limit, search_radius, rvcut, convergcut, radec, output_directory, showplots, verbose, DoGALEX, DoWISE, DoROSAT)
#     171     print(sqltext)
#     172     print()
# --> 174 job = Gaia.launch_job_async(sqltext , dump_to_file=False)
#     175 r = job.get_results()
#     177 #print(r.columns)
#
# File ~\anaconda3\envs\ASTR502\Lib\site-packages\astroquery\gaia\core.py:1154, in GaiaClass.launch_job_async(self, query, name, output_file, output_format, verbose, dump_to_file, background, upload_resource, upload_table_name, autorun)
#    1113 def launch_job_async(self, query, *, name=None, output_file=None,
#    1114                      output_format="votable_gzip", verbose=False,
#    1115                      dump_to_file=False, background=False,
#    1116                      upload_resource=None, upload_table_name=None,
#    1117                      autorun=True):
#    1118     """Launches an asynchronous job
#    1119
#    1120     Parameters
#    (...)   1152     A Job object
#    1153     """
# -> 1154     return TapPlus.launch_job_async(self, query=query,
#    1155                                     name=name,
#    1156                                     output_file=output_file,
#    1157                                     output_format=output_format,
#    1158                                     verbose=verbose,
#    1159                                     dump_to_file=dump_to_file,
#    1160                                     background=background,
#    1161                                     upload_resource=upload_resource,
#    1162                                     upload_table_name=upload_table_name,
#    1163                                     autorun=autorun,
#    1164                                     format_with_results_compressed=('votable_gzip',))
#
# File ~\anaconda3\envs\ASTR502\Lib\site-packages\astroquery\utils\tap\core.py:480, in Tap.launch_job_async(self, query, name, output_file, output_format, verbose, dump_to_file, background, upload_resource, upload_table_name, autorun, maxrec, format_with_results_compressed)
#     478                 job.save_results(verbose=verbose)
#     479             else:
# --> 480                 job.get_results()
#     481                 log.info("Query finished.")
#     482 return job
#
# File ~\anaconda3\envs\ASTR502\Lib\site-packages\astroquery\utils\tap\model\job.py:247, in Job.get_results(self)
#     244     return None
#     245 else:
#     246     # async: result is in the server once the job is finished
# --> 247     self.__load_async_job_results()
#     248     return self.results
#
# File ~\anaconda3\envs\ASTR502\Lib\site-packages\astroquery\utils\tap\model\job.py:353, in Job.__load_async_job_results(self, debug)
#     348     print(resultsResponse.getheaders())
#     350 resultsResponse = self.__handle_redirect_if_required(resultsResponse,
#     351                                                      verbose=debug)
#     352 isError = self.connHandler. \
# --> 353     check_launch_response_status(resultsResponse,
#     354                                  debug,
#     355                                  200)
#     356 self._phase = phase
#     357 if phase == 'ERROR':
#
# File ~\anaconda3\envs\ASTR502\Lib\site-packages\astroquery\utils\tap\conn\tapconn.py:688, in TapConn.check_launch_response_status(self, response, debug, expected_response_status, raise_exception)
#     686     errMsg = taputils.get_http_response_error(response)
#     687     print(response.status, errMsg)
# --> 688     raise requests.exceptions.HTTPError(errMsg)
#     689 else:
#     690     return isError
#
# HTTPError: Error 500:
# null

# %%
# Out:
# '19.09913444519040'
