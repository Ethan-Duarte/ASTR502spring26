# %% [markdown]
# Setup

# %%
import Comove
# Out:
# Warning: the passwords of all user accounts have been inactivated.              Please visit https://cas.cosmos.esa.int/cas/passwd to set a new one. Workaround solutions for the Gaia Archive issues following the infrastructure upgrade: https://www.cosmos.esa.int/web/gaia/news#WorkaroundArchive
# DEBUG 0
# DEBUG 1

# %%
import astropy.units as u
from astropy.coordinates import SkyCoord
from astroquery.gaia import Gaia
from astroquery.simbad import Simbad
import numpy as np
import pandas as pd
import os
import shutil
import time

# --- Load targets ---
arr = np.genfromtxt(
    "Targets.csv",
    delimiter=",",
    dtype=str,
    encoding="utf-8"
)

"""
--Header to ids-- 
hostname = 1
gaia id  = 2
ra       = 6
dec      = 7
st_rv    = 21
st_e_rv  = 22
"""

Simbad.server = "simbad.cds.unistra.fr"

# ---------- helpers ----------
def safe_name(s: str) -> str:
    """Make a Windows-safe folder/name (no spaces/colons/slashes, etc.)."""
    bad = '<>:"/\\|?*'
    for ch in bad:
        s = s.replace(ch, "_")
    return s.strip().replace(" ", "_")

def rename_file(star_name, full_directory_location, filename, gaia_id):
    og_path = os.path.join(full_directory_location, filename)
    if str(gaia_id) in filename:
        new_filename = filename.replace(str(gaia_id), star_name)
        new_path = os.path.join(full_directory_location, new_filename)
        os.replace(og_path, new_path)

def rename_directory(star_name, directory_location, gaia_id):
    """
    Renames files inside directory by replacing gaia_id -> star_name,
    then renames the directory itself the same way.
    Returns the NEW directory path.
    """
    full_path = os.path.abspath(directory_location)

    # rename files inside
    for filename in os.listdir(full_path):
        rename_file(star_name, full_path, filename, str(gaia_id))

    # rename directory
    if str(gaia_id) in os.path.basename(full_path):
        new_path = os.path.join(os.path.dirname(full_path),
                                os.path.basename(full_path).replace(str(gaia_id), star_name))
        os.rename(full_path, new_path)
        return new_path

    return full_path

# ---------- run one target ----------
targetIndex = 507

host_label = safe_name(arr[targetIndex][1])          # hostname column
gaia_id    = arr[targetIndex][2]                    # gaia id column

targname = f"Gaia DR3 {gaia_id}"
rd = [arr[targetIndex][6], arr[targetIndex][7]]     # ra/dec columns (strings OK if Comove expects that)

radvel = float(arr[targetIndex][21])                # st_rv column

vlim = 4.0
srad = 15.0

# --- Clean up any previous output folder BEFORE running ---
old_folder_by_host = f"./{host_label}_friends"
old_folder_by_id   = f"./{gaia_id}_friends"

if os.path.exists(old_folder_by_host):
    print(f"Cleaning up existing folder: {old_folder_by_host}")
    shutil.rmtree(old_folder_by_host)
elif os.path.exists(old_folder_by_id):
    print(f"Cleaning up existing folder: {old_folder_by_id}")
    shutil.rmtree(old_folder_by_id)

# --- Timed run (run ONCE) ---
t0 = time.perf_counter()
try:
    output_location = Comove.findfriends(
        targname,
        radvel,
        velocity_limit=vlim,
        search_radius=srad,
        radec=rd,                 # you had rd defined; pass it explicitly
        output_directory=None,
        verbose=False,
        showplots=False
    )
finally:
    print(f"Runtime: {time.perf_counter() - t0:.2f} s")

print("Comove output folder:", output_location)

# --- Rename output folder and internal files to hostname label ---
# (Only if Comove returned a valid folder path)
if output_location and os.path.exists(output_location):
    new_location = rename_directory(host_label, output_location, gaia_id)
    print("Renamed folder to:", new_location)
# Out:
# Asking Gaia for precise coordinates
# INFO: Query finished. [astroquery.utils.tap.core]
# Querying Gaia for neighbors
# Parallax cut:  0.5
# INFO: Query finished. [astroquery.utils.tap.core]
# DEBUG 2
# Populating RV table
# DEBUG 3
# DEBUG 3
# Number with RV outside/inside selection range:  3   0
# (-0.22324147234540956, -0.2537796283438367, 0.0004614183688906928)
# XYZ (pc)   :  -223.2 -253.8 0.5
# UVW (km/s) :  -17.86 -52.2 -11.59
# Convergent point:  <SkyCoord (ICRS): (ra, dec, distance) in (deg, deg, )
#     (109.74346675, -39.21179501, 999999.9)>
# Searching on neighbors in GALEX
# Searching on neighbors in 2MASS
# Searching on neighbors in WISE
# C:\Users\dshin\ASTR502\ASTR502spring26\Comove.py:1167: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ddd = ax1.scatter( [ spt[yy[x]] ] , [ W13[yy[x]] ] , \
#
# C:\Users\dshin\ASTR502\ASTR502spring26\Comove.py:1167: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'vmin', 'vmax' will be ignored
#   ddd = ax1.scatter( [ spt[yy[x]] ] , [ W13[yy[x]] ] , \
#
# Searching on neighbors in ROSAT
# Creating Output Tables with Results
# Runtime: 44.90 s
# Comove output folder: ./GaiaDR33032656414642552192_friends/
# Renamed folder to: C:\Users\dshin\ASTR502\ASTR502spring26\GaiaDR3TOI-4214_friends

# %%
run run_stars.py
# Out:
# Warning: the passwords of all user accounts have been inactivated.              Please visit https://cas.cosmos.esa.int/cas/passwd to set a new one. Workaround solutions for the Gaia Archive issues following the infrastructure upgrade: https://www.cosmos.esa.int/web/gaia/news#WorkaroundArchive
# DEBUG 0
# DEBUG 1
#
# [1] HIP_65_A | Gaia DR3 4923860051276772608 | RV=21.18428993
# INFO: Query finished. [astroquery.utils.tap.core]
# Asking Gaia for precise coordinates
# 404 Error 404:
# Job '94797397-112c-11f1-91f6-bc97e148b76b-O' not found.
#   ERROR: HTTPError("Error 404:\nJob '94797397-112c-11f1-91f6-bc97e148b76b-O' not found.")
#   Runtime: 5.36 s
#
# [2] WASP-136 | Gaia DR3 2441013811932929280 | RV=11.21512794
# INFO: Query finished. [astroquery.utils.tap.core]
# Asking Gaia for precise coordinates
# INFO: Query finished. [astroquery.utils.tap.core]
# Querying Gaia for neighbors
# Parallax cut:  0.5
# INFO: Query finished. [astroquery.utils.tap.core]
# DEBUG 2
# Populating RV table
# DEBUG 3
# C:\Users\Eef\MY SHIT\Documents\ASTR502spring26\Comove.py:401: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax1.axis([ (max(r['pmra'][zz2]) + 0.05*np.ptp(r['pmra'][zz2]) ) , \
#
# C:\Users\Eef\MY SHIT\Documents\ASTR502spring26\Comove.py:401: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax1.axis([ (max(r['pmra'][zz2]) + 0.05*np.ptp(r['pmra'][zz2]) ) , \
#
# DEBUG 3
# Number with RV outside/inside selection range:  0   0
# C:\Users\Eef\MY SHIT\Documents\ASTR502spring26\Comove.py:525: UserWarning: Adding colorbar to a different Figure <Figure size 1200x800 with 2 Axes> than <Figure size 1200x800 with 2 Axes> which fig.colorbar is called on.
#   cb = plt.colorbar(ccc , ax=ax1)
#
# (0.0042867882940921765, 0.09932014704816988, -0.24956863991791678)
# XYZ (pc)   :  4.3 99.3 -249.6
# UVW (km/s) :  -8.38 12.55 -7.22
# Convergent point:  <SkyCoord (ICRS): (ra, dec, distance) in (deg, deg, )
#     (13.78271445, 37.28251202, 999999.9)>
# C:\Users\Eef\MY SHIT\Documents\ASTR502spring26\Comove.py:730: UserWarning: Adding colorbar to a different Figure <Figure size 1600x1600 with 4 Axes> than <Figure size 1600x1600 with 4 Axes> which fig.colorbar is called on.
#   cb = plt.colorbar( ddd , cax=cbaxes )
#
# Searching on neighbors in GALEX
# Searching on neighbors in 2MASS
# Searching on neighbors in WISE
# Searching on neighbors in ROSAT
# Creating Output Tables with Results
#   Runtime: 20.29 s
#   Saved run folder -> ALL_RUNS\GaiaDR32441013811932929280_friends
#
# [3] KELT-1 | Gaia DR3 2881784280929695360 | RV=-14.20667267
# 404 Error 404:
# Job 'a6648d0a-112c-11f1-91f6-bc97e148b76b-O' not found.
# Asking Gaia for precise coordinates
# INFO: Query finished. [astroquery.utils.tap.core]
# Querying Gaia for neighbors
# Parallax cut:  0.5
# INFO: Query finished. [astroquery.utils.tap.core]
# DEBUG 2
# Populating RV table
# DEBUG 3
# DEBUG 3
# Number with RV outside/inside selection range:  3   2
# (-0.096013454625177, 0.23175261054254237, -0.10377177322944975)
# XYZ (pc)   :  -96.0 231.8 -103.8
# UVW (km/s) :  19.3 -9.21 -1.26
# Convergent point:  <SkyCoord (ICRS): (ra, dec, distance) in (deg, deg, )
#     (250.15585233, -51.63205578, 999999.9)>
# Searching on neighbors in GALEX
# Searching on neighbors in 2MASS
# Searching on neighbors in WISE
# C:\Users\Eef\MY SHIT\Documents\ASTR502spring26\Comove.py:1167: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ddd = ax1.scatter( [ spt[yy[x]] ] , [ W13[yy[x]] ] , \
#
# C:\Users\Eef\MY SHIT\Documents\ASTR502spring26\Comove.py:1167: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'vmin', 'vmax' will be ignored
#   ddd = ax1.scatter( [ spt[yy[x]] ] , [ W13[yy[x]] ] , \
#
# Searching on neighbors in ROSAT
# Creating Output Tables with Results
#   Runtime: 22.85 s
#   Saved run folder -> ALL_RUNS\GaiaDR32881784280929695360_friends
#
# [4] HATS-34 | Gaia DR3 4904523077718046720 | RV=19.81319046
# INFO: Query finished. [astroquery.utils.tap.core]
# Asking Gaia for precise coordinates
# INFO: Query finished. [astroquery.utils.tap.core]
# Querying Gaia for neighbors
# Parallax cut:  0.5
# 404 Error 404:
# Job 'bd108a18-112c-11f1-91f6-bc97e148b76b-O' not found.
#   ERROR: HTTPError("Error 404:\nJob 'bd108a18-112c-11f1-91f6-bc97e148b76b-O' not found.")
#   Runtime: 13.75 s
#
# [5] WASP-96 | Gaia DR3 4990044668377961984 | RV=-1.097559452
# INFO: Query finished. [astroquery.utils.tap.core]
# Asking Gaia for precise coordinates
# INFO: Query finished. [astroquery.utils.tap.core]
# Querying Gaia for neighbors
# Parallax cut:  0.5
# INFO: Query finished. [astroquery.utils.tap.core]
# DEBUG 2
# Populating RV table
# DEBUG 3
# DEBUG 3
# Number with RV outside/inside selection range:  0   1
# (0.1077136923792395, -0.07707714916723162, -0.32372616571396556)
# XYZ (pc)   :  107.7 -77.1 -323.7
# UVW (km/s) :  -38.74 -15.88 -7.92
# Convergent point:  <SkyCoord (ICRS): (ra, dec, distance) in (deg, deg, )
#     (88.44254237, 4.40066456, 999999.9)>
# Searching on neighbors in GALEX
# Searching on neighbors in 2MASS
# Searching on neighbors in WISE
# Searching on neighbors in ROSAT
# Creating Output Tables with Results
#   Runtime: 18.53 s
#   Saved run folder -> ALL_RUNS\GaiaDR34990044668377961984_friends
#
# [6] TOI-198 | Gaia DR3 2333676738050041728 | RV=19.7009964
# 500 Error 500:
# null
# Asking Gaia for precise coordinates
# INFO: Query finished. [astroquery.utils.tap.core]
# Querying Gaia for neighbors
# Parallax cut:  4.205915434334417
#   ERROR: HTTPError('500')
#   Runtime: 8.69 s
#
# [7] WASP-44 | Gaia DR3 2424406513428936832 | RV=-3.095204592
# 500 Error 500:
# null
# Asking Gaia for precise coordinates
# INFO: Query finished. [astroquery.utils.tap.core]
# Querying Gaia for neighbors
# Parallax cut:  0.5

# %%
# Out:
# '19.09913444519040'
