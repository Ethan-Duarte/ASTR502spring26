# %%
run run_stars
# Out:
# ...
# Logging to: C:\Users\Eef\MY SHIT\Documents\ASTR502spring26\run_log.csv
#
# [0] HIP_65_A | Gaia DR3 4923860051276772608 | RV=21.18428993
# INFO: Query finished. [astroquery.utils.tap.core]
#   NOTE: cone would be huge; cap-by-angle 10.0°: 40.00 -> 10.74 pc
#   Attempt 1/4 (timeout=300s)
#   ERROR (attempt 1/4): HTTPError('Error 500:\nnull')
#   Runtime: 14.51 s
#   Retrying after 10s...
#   Attempt 2/4 (timeout=300s)
#   ERROR (attempt 2/4): HTTPError('Error 500:\nnull')
#   Runtime: 18.34 s
#   Retrying after 20s...
#   Attempt 3/4 (timeout=300s)
#   ERROR (attempt 3/4): HTTPError("Error 404:\nJob '1343c2be-114f-11f1-91f6-bc97e148b76b-O' not found.")
#   Runtime: 15.27 s
#   Retrying after 40s...
#   Attempt 4/4 (timeout=300s)
#   Runtime: 122.09 s (attempt 4)
#   Saved run folder -> ALL_RUNS\HIP_65_A_friends
#
# [1] WASP-136 | Gaia DR3 2441013811932929280 | RV=11.21512794
# 404 Error 404:
# Job '77d6ff15-114f-11f1-91f6-bc97e148b76b-O' not found.
#   Attempt 1/4 (timeout=300s)
# ...
