# %%
run run_stars
# Out:
# ...
# Logging to: C:\Users\dshin\Documents\ASTR502spring26\run_log.csv
#
# [21] HATS-46 | Gaia DR3 4919771654727611008 | RV=-32.45669174
# INFO: Query finished. [astroquery.utils.tap.core]
#   Attempt 1/4 (timeout=300s)
