# %%
import json
from astroquery.gaia import Gaia
from pathlib import Path

CREDS_PATH = Path("gaia_credentials.json")

with CREDS_PATH.open("r", encoding="utf-8") as f:
    creds = json.load(f)

Gaia.login(user=creds["user"], password=creds["password"])
print("Gaia login OK")
# Out:
# The archive is unstable and may perform below expectations. If launching multiple, consecutive, heavy queries through Python, please space them out (e.g., using sleep(1)) to avoid overloading the system. Please contact the Gaia helpdesk in case of questions (https://www.cosmos.esa.int/web/gaia/gaia-helpdesk). Workaround solutions for the issues following the December 2025 infrastructure upgrade: https://www.cosmos.esa.int/web/gaia/news#WorkaroundArchive
# INFO: Login to gaia TAP server [astroquery.gaia.core]
# INFO: OK [astroquery.utils.tap.core]
# INFO: Login to gaia data server [astroquery.gaia.core]
# INFO: OK [astroquery.utils.tap.core]
# Gaia login OK

# %%
from run_stars import run_stars

run_stars(
    mode=0,
    csv_path="Targets.csv",
    start_index=1475,
    end_index=2000,
    vlim=5.0,
    srad=70.0,
    verbose=True,
    attempt_timeout_s=600,
    max_attempts=1,
    friends_dir="FRIENDS",
    log_path="run_log.csv",
    force_rerun = False
)
# Out:
# [1475] Kepler-1385 | Gaia DR3 2107492421531881500 | RV=-11.11898899
#   Attempt 1/1 (timeout=600s)
#   ERROR: RuntimeError('No Gaia row found for source_id=2107492421531881500')
#   Runtime: 4.71 s
#
# [1476] Kepler-1494 | Gaia DR3 2105168775506130000 | RV=
#   SKIP: Missing/invalid RV
#
# [1477] Kepler-714 | Gaia DR3 2105192999121723600 | RV=
#   SKIP: Missing/invalid RV
#
# [1478] Kepler-1408 | Gaia DR3 2106958363820214000 | RV=-30.05275917
#   Attempt 1/1 (timeout=600s)
#   ERROR: RuntimeError('No Gaia row found for source_id=2106958363820214000')
#   Runtime: 4.08 s
#
# [1479] Kepler-777 | Gaia DR3 2105358166383528000 | RV=
#   SKIP: Missing/invalid RV
#
# [1480] TOI-1749 | Gaia DR3 2253774094189458400 | RV=-2.834845781
#   Attempt 1/1 (timeout=600s)
#   ERROR: RuntimeError('No Gaia row found for source_id=2253774094189458400')
#   Runtime: 4.13 s
#
# [1481] TOI-1749 | Gaia DR3 2253774094189458400 | RV=-2.834845781
#   SKIP: duplicate Gaia source_id in this run
#
# [1482] TOI-1749 | Gaia DR3 2253774094189458400 | RV=-2.834845781
#   SKIP: duplicate Gaia source_id in this run
#
# [1483] Kepler-613 | Gaia DR3 2107102988257870300 | RV=0.8496356606
#   Attempt 1/1 (timeout=600s)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from run_stars import run_stars
# ----> 3 run_stars(
#       4     mode=0,
#       5     csv_path="Targets.csv",
#       6     start_index=1475,
#       7     end_index=2000,
#       8     vlim=5.0,
#       9     srad=70.0,
#      10     verbose=True,
#      11     attempt_timeout_s=600,
#      12     max_attempts=1,
#      13     friends_dir="FRIENDS",
#      14     log_path="run_log.csv",
#      15     force_rerun = False
#      16 )
#
# File ~\MY SHIT\Documents\ASTR502spring26\ASTR502spring26\April Fixes\run_stars.py:348, in run_stars(**kwargs)
#     347 def run_stars(**kwargs):
# --> 348     return run(**kwargs)
#
# File ~\MY SHIT\Documents\ASTR502spring26\ASTR502spring26\April Fixes\run_stars.py:245, in run(mode, hostnames, csv_path, start_index, end_index, vlim, srad, verbose, attempt_timeout_s, max_attempts, base_backoff_s, friends_dir, log_path, sleep_between_targets_s, dedupe_by_gaia_id, force_rerun)
#     243 t0 = time.perf_counter()  # start timing
#     244 p.start()  # start worker
# --> 245 p.join(int(attempt_timeout_s))  # wait up to timeout
#     247 if p.is_alive():
#     248     p.terminate()  # kill hung worker
#
# File ~\anaconda3\envs\ASTR502\Lib\multiprocessing\process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File ~\anaconda3\envs\ASTR502\Lib\multiprocessing\popen_spawn_win32.py:112, in Popen.wait(self, timeout)
#     109 else:
#     110     msecs = max(0, int(timeout * 1000 + 0.5))
# --> 112 res = _winapi.WaitForSingleObject(int(self._handle), msecs)
#     113 if res == _winapi.WAIT_OBJECT_0:
#     114     code = _winapi.GetExitCodeProcess(self._handle)
#
# KeyboardInterrupt:
